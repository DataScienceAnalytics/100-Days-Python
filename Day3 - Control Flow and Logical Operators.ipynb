# %%
number = int(input('input your integer: '))
if number % 2 == 0:
    print('This is a even number')
else:
    print('This is an odd number')
# Out:
# input your integer: 87
# This is an odd number

# %% [markdown]
# ### Difference between if + if and if + elif

# %% [markdown]
# - Multiple if's means your code would go and check all the if conditions,
# - where as in case of elif, if one if condition satisfies it would not check other

# %%
#You might get issues if you use if+if+else
#That is because BOTH if statements are being evaluated. 
#The computer sees them as two separate statements: 
''' The first one is true and so "pay 5" is printed.
    The second if statement is false and 
    therefore the else part is executed printing "pay 12"'''

age = int(input('input your age: '))
if age < 12:
    print('pay 5')
if age <= 18:
    print('pay 7')
else:
    print('pay 12')
# Out:
# input your age: 10
# pay 5
# pay 7

# %% [markdown]
# You can see that elif is slightly faster. <br> This would be more apparent if there were more ifs and more elifs.

# %%
#Run time difference between if if and if elif
def multipleif(text):
    if text == 'sometext':
        print(text)
    if text == 'nottext':
        print("notanytext")

def eliftest(text):
    if text == 'sometext':
        print(text)
    elif text == 'nottext':
        print("notanytext")

text = "sometext"

timeit multipleif(text)
100000 loops, best of 3: 5.22 us per loop

timeit eliftest(text)
100000 loops, best of 3: 5.13 us per loop

# %% [markdown]
# ### Rule of thumb:
# - When using multiple condition. Use <b>elif</b> after if instead of <b>if</b>

# %% [markdown]
# ## BMI Calculator 2.0
# Write a program that interprets the Body Mass Index (BMI) based on a user's weight and height.
#
# It should tell them the interpretation of their BMI based on the BMI value.
#
# - Under 18.5 they are underweight
# - Over 18.5 but below 25 they have a normal weight
# - Over 25 but below 30 they are slightly overweight
# - Over 30 but below 35 they are obese
# - Above 35 they are clinically obese.

# %%
# 🚨 Don't change the code below 👇
height = float(input("enter your height in m: "))
weight = float(input("enter your weight in kg: "))
# 🚨 Don't change the code above 👆

BMI = height/(weight**2)
if BMI < 18.5:
    print('Underweight')
elif BMI < 25:
    print('Normal weight')
elif BMI < 30:
    print('Slightly overweight')
elif BMI < 35:
    print('Obese')
else:
    print('Clinically obese')
# Out:
# enter your height in m: 177
# enter your weight in kg: 57
# Underweight

# %% [markdown]
# ## Leap Year Challenge

# %%
year = int(input('Input the year here: '))

if year % 4 == 0:
    if year % 100!=0:
        print('Leap year')
    else:
        if year % 400==0:
            print('Leap year')
        else:
            print('Not leap year')
else:
    print('Not Leap year')
# Out:
# Input the year here: 2016
# Not leap year

# %% [markdown]
# ## Multiple if condition
# - The right hand side code will check all the condition while the left one will stop once one of them is true

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pizza Order Practice

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
size = input('Input the size of pizza here(S or M or L): ')
add_pepperoni = input('Do you need to add pepperoni(Y or N): ')
extra_cheese = input('Do you need to add extra cheese(Y or N): ')
# Out:
# Input the size of pizza here(S or M or L): L
# Do you need to add pepperoni(Y or N): Y
# Do you need to add extra cheese(Y or N): N

# %%
bill = 0
if size =='S': 
    bill = 15
    if add_pepperoni =='Y':
        bill = bill+2
elif size=='M':
    bill=20
    if add_pepperoni =='Y':
        bill = bill+3
elif size=='L':
    bill=25
    if add_pepperoni =='Y':
        bill = bill+3
if extra_cheese=='Y':
    bill+=1
print(f"Your final bill is: ${bill}.")
# Out:
# Your final bill is: $28.

# %% [markdown]
# ## Logical Operator
# - AND / OR / NOT

# %% [markdown]
# ### Love calculator exercise

# %%
# 🚨 Don't change the code below 👇
print("Welcome to the Love Calculator!")
name1 = input("What is your name? \n")
name2 = input("What is their name? \n")
# 🚨 Don't change the code above 👆
#Write your code below this line 👇
# Out:
# Welcome to the Love Calculator!
# What is your name?
# Billie Eillish
# What is their name?
# Justin Biber

# %%
name1 = name1.lower()
name2 = name2.lower()
name_merge = name1+name2

true_count_list = [name_merge.count('true'[i]) for i in range(len('true'))]
true_count = sum(true_count_list)
love_count_list = [name_merge.count('love'[i]) for i in range(len('love'))]
love_count = sum(love_count_list)

# %%
true_love_index = int(str(true_count)+str(love_count))
if true_love_index < 10 or true_love_index > 90:
    print(f"Your score is {true_love_index}, you go together like coke and mentos.")
elif true_love_index > 40 and true_love_index < 50:
    print(f"Your score is {true_love_index}, you are alright together.")
else:
    print(f"Your score is {true_love_index}.")
# Out:
# Your score is 67.

# %% [markdown]
# ### Treasure island exercise

# %%
lr=input('You\'re at a crossroad. Where do you want to go? Type "left" or "right"').lower()

if lr=='right':
    print("You fell into a hole. Game Over.")
else:
    sw=input('You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across.').lower()
    if sw=='swim':
        print("You get attacked by an angry trout. Game Over.")
    else:
        wd=input("You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which colour do you choose?").lower()
        if wd=='red':
            print("It's a room full of fire. Game Over.")
        elif wd=='blue':
            print("You enter a room of beasts. Game Over.")
        elif wd=='yellow':
            print("You found the treasure! You Win!")
        else:
            print("You chose a door that doesn't exist. Game Over.")
# Out:
# You're at a crossroad. Where do you want to go? Type "left" or "right"left
# You've come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across.wait
# You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which colour do you choose?yellow
# You found the treasure! You Win!
