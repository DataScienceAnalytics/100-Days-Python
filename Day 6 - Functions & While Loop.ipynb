# %% [markdown]
# ## Robot Path Challenge
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Even with one space the indentation still works. No specific number required but 4 spaces is the official format
def hello():
 print('hello')

# %%
hello()
# Out:
# hello

# %% [markdown]
# ## Use While Loop to Find a Flag appeared on random location

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## For vs While
# - Use for when you want to iterate something over
# - Use while when you want to use some function until something is met

# %% [markdown]
# ## Exercise 3 - Different Height Cross

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Exercise 4 - Walk out of Maze!

# %% [markdown]
# ![image.png](attachment:image.png)
